# %% [markdown]
# Hello World~!

# %% [markdown]
# # Hello World!

# %% [markdown]
# ## Hello World!

# %% [markdown]
# ### Hello World!

# %% [markdown]
# - 1
# - 2

# %%
1
# Out:
# 1

# %% [markdown]
# #파이썬의 기본 요소

# %% [markdown]
# - Python Program = Script 이라 함
# - Shell : 대화형 shell (표시 : >>>)
# - 대화형 shell : 변수 선언, 함수 호출, 라이브러리 사용 등 파이썬 코드를 실행
# - 대화형 shell 종료 : exit() 함수 호출, Ctrl+D(Unix/Linux/macOS), Ctrl+Z(Windows)
# - IPython 고급 대화형 쉘 : 표준 Python shell보다 더 많은 기능을 제공
# - 설치 방법 : pip install ipython

# %% [markdown]
# ##Print func. 활용

# %% [markdown]
# - 결과를 출력하기 위해 print()함수를 사용

# %% [markdown]
# ###숫자 출력

# %%
print(1)
# Out:
# 1

# %%
print(3)
# Out:
# 3

# %%
print(123)
# Out:
# 123

# %%
print(1,2,3)
# Out:
# 1 2 3

# %% [markdown]
# ###문자 출력

# %% [markdown]
# - 문자 출력을 위해서는 '',""를 사용한다.

# %%
print(Hello World of Python!!)
# Out:
#   File "<ipython-input-9-b56d75d87c8f>", line 1
#     print(Hello World of Python!!)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('Hello World of Python!!')
# Out:
# Hello World of Python!!

# %%
print("Hello World of Python!!")
# Out:
# Hello World of Python!!

# %%
print("Hello World of Python!!Hello World of Python!!Hello World of Python!!")
# Out:
# Hello World of Python!!Hello World of Python!!Hello World of Python!!

# %%
print("Hello World of Python!!","Hello World of Python!!"+"Hello World of Python!!")
# Out:
# Hello World of Python!! Hello World of Python!!Hello World of Python!!

# %% [markdown]
# ###숫자, 문자 출력

# %%
print("1 다음에 표시할 숫자는", 2) ## 2를 숫자로 인식
# Out:
# 1 다음에 표시할 숫자는 2

# %%
print("1 다음에 표시할 숫자는 2") ## 2를 문자로 인식
# Out:
# 1 다음에 표시할 숫자는 2

# %% [markdown]
# ###기타 출력

# %%
print('Hello World, ')
# Out:
# Hello World,

# %%
print('Hello World of Python.\nNice to meet you') ##\n을 넣으면 줄 바꿈
# Out:
# Hello World of Python.
# Nice to meet you

# %%
print(1, end= ", ")
print(2)
# Out:
# 1, 2

# %%
a = 1
b, c = 2, 3
d = b + c
print("a = ", a)
print("d = ", d)
# Out:
# a =  1
# d =  5

# %% [markdown]
# ###type() 함수

# %% [markdown]
# - print()함수에 type()함수를 사용하면 변수의 자료형을 확인 할 수 있음

# %%
dummy = "toy"
temp = 3.141592653
print(type(dummy)) # <class'str'>
print(type(temp)) # <class 'float'>
# Out:
# <class 'str'>
# <class 'float'>

# %% [markdown]
# ###변수 포멧

# %% [markdown]
# - %변수 포멧으로 사용
# - 변수 포멧을 사용하여 문자열에 변수 값을 삽입
# - %s : 문자열
# - %c : 문자
# - %d : 정수
# - %f : 실수

# %%
x = 10
print("x is %d" %x)

y = "code"
print("y is %s" %y)

print("x is %d and y is %s" % (x, y))
# Out:
# x is 10
# y is code
# x is 10 and y is code

# %% [markdown]
# ###format 함수 이용

# %% [markdown]
# - format 함수를 이용하면 변수의 타입을 명시하지 않아도 됨
# - 순서 또는 변수 이름을 통해 원하는 변수를 포멧에 맞춰 넣어줘야 함

# %%
x, y = 10, "code"

print("x is {0}".format(x))
print("y is {new_x}".format(new_x=x))
print("\n")
print("x is {0} and y is {1}".format(x,y))
print("x is {new_x} and y is {new_y}".format(new_x=x, new_y=y))
print("y is {1} and x is {0}".format(x,y))
print("y is {new_y} and x is {new_x}".format(new_x=x, new_y=y))
# Out:
# x is 10
# y is 10
#
#
# x is 10 and y is code
# x is 10 and y is code
# y is code and x is 10
# y is code and x is 10

# %% [markdown]
# ###f 문자열 포멧

# %% [markdown]
# - 문자열 앞에 f를 붙이면, 중괄호와 변수 이름만으로 문자열에 원하는 변수를 삽입할 수 있음

# %%
x, y = 10, "code"

##print("x is {0}", %x)
print("x is %d" %x)

print(f"x is {x}")
print(f"x is {y}")

print("x is {x} and y is {y}")
print(f"x is {x} and y is {y}")
# Out:
# x is 10
# x is 10
# x is code
# x is {x} and y is {y}
# x is 10 and y is code

# %% [markdown]
# ###실수형 변수를 소수점 맞춰 출력

# %% [markdown]
# - 4f == 소수 4째 자리까지 반올림 출력
# - 1. 변수 포멧 : %를 이용
# - 2. format 함수 : 기존 포멧 {0}dp :를 붙여 사용
# - 3. f문자열 포멧 이용 : 기존 포멧에 :를 붙여 사용

# %%
# %를 이용
x = 3.141592653
print("%.4f" %x)

# 기존 포멧 {0}에 :를 붙여 사용
x = 3.141592653
print("{0:.4f}".format(x))

# f 문자열 포멧 이용
x = 3.141592653
print(f"{x:.4f}")
# Out:
# 3.1416
# 3.1416
# 3.1416

# %% [markdown]
# ###변수(Variable)
#
# 1.   항목 추가
# 2.   항목 추가

# %% [markdown]
# - 변수는 임시로 또는 영구적으로 값을 기억해두기 위한 저장소

# %%
# 왼쪽에 변수이름 = 변수에 넣으려는 숫자 또는 문자
x = 2
y = 3
z = "result"

# %%
print(x,y)
# Out:
# 2 3

# %%
print(x+y)
# Out:
# 5

# %%
e = x + y
print(f"{z} = {e}")
print(f"{z} = "f"{e}")
# Out:
# result = 5
# result = 5

# %% [markdown]
# ##변수 정의

# %% [markdown]
# - 변수 생성 : 변수에 값을 할당함으로써 변수를 생성
# - 변수 이름 : 문자와 숫자, 밑줄(_)을 포함할 수 있으나, 숫자로 시작할 수는 없음
# - 파이썬은 대소문자를 구분하므로 Name과 name은 서로 다른 변수
# - 변수 할당(assignment) '='기호를 기준으로 왼쪽은 변수명, 오른쪽은 표현 또는 표현식으로 표기
# - 파이썬에는 몇개의 예약어(reserved word)는 변수명으로 사용할 수 없음, ex)and, break, class, if, not etc.

# %%
name = "Alice"  # 문자열 변수
age = 30        # 정수 변수
height = 5.5    # 부동 소수점 변수
is_adult = True # 불리언 변수

# %% [markdown]
# ##변수 사용

# %% [markdown]
# - 변수에 값을 할당한 후에는 변수 이름을 통해 해당 값을 사용

# %%
print(name) # Alice 출력
new_age = age + 10 # age 변수에 10을 더한 값을 new_age 변수에 할당
print(new_age) # 40 출력
# Out:
# Alice
# 40

# %% [markdown]
# ##동적 타이핑

# %% [markdown]
# ##불리언(Boolean)

# %% [markdown]
# - 불리언 타입은 True와 False의 두 가지 값
# - 조건문의 결과를 나타내는 데 주로 사용

# %%
is_adult = True
is_teenager = False

# %% [markdown]
# - 논리 연산자(and, or, not)와 함께 사용될 때 유용

# %%
#논리 연산
print(True and False) #False
print(True or False) #False
print(not True) #False
# Out:
# False
# True
# False

# %% [markdown]
# ###<추가 내용>

# %% [markdown]
# 2진수(0b),8진수(0o),16진수(0x)표현

# %%
print(15)
print(0b1111)
print(0o17)
print(0xF)
# Out:
# 15
# 15
# 15
# 15

# %% [markdown]
# 숫자를 문자형으로 변환

# %% [markdown]
# - bin(), oct(), hex()

# %%
print(bin(15))
print(oct(15))
print(hex(15))
# Out:
# 0b1111
# 0o17
# 0xf

# %% [markdown]
# 문자열을 숫자형으로 변환

# %% [markdown]
# - int('문자열', 진수)

# %%
print(int('0b1111', 2))
print(int('0o17', 8))
print(int('0xf', 16))
# Out:
# 15
# 15
# 15

# %% [markdown]
# format() 활용

# %% [markdown]
# - format(15,'b')

# %%
print(format(15, 'b'))
print(format(15, 'o'))
print(format(15, 'x'))
print(format(15, 'd'))
# Out:
# 1111
# 17
# f
# 15

# %% [markdown]
# ###주석처리

# %% [markdown]
# - 한 줄 주석 처리 : #을 문장 앞에 작성

# %%
#print('Hello World')

# %% [markdown]
# - 여러 줄 주석 처리 : 큰 따옴표 3개 또는 작은 따옴표 3개

# %%
"""
print('Hello World')
print('Hello World')
print('Hello World')
print('Hello World')
"""
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# colab 여러줄 주석 처리 : ctrl+/

# %%
# print('Hello World')
# print('Hello World')
# print('Hello World')
# print('Hello World')

# print('Hello World')
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
