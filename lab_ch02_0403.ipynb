# %% [markdown]
# #Chap.02 변수와 연산자

# %% [markdown]
# ##2.1 변수

# %% [markdown]
# - 변수(Variable) : 프로그램이 실행되는 동안 값을 저장하는 공간
#     - 변수 이름 = 값
# - 연산(Operation) : 덧셈, 뺄셈 등과 같이 일정한 규칙에 따라 계산을하는 것
#     - 사칙연산
#     - 관계연산
#     - 논리연산

# %%
a = 7
a += 7
print(a)
# Out:
# 14

# %%
a = 100
a += 10
print(a)
a *= 2
print(a)
a //= 7
print(a)
a %= 7
print(a)
# Out:
# 110
# 220
# 31
# 3

# %% [markdown]
# ##2.2 자료형

# %% [markdown]
# - 자료형(data type) : 기본 자료형, 구조적 자료형
# - 정수(integer)
# - 문자열(string)
# - 부동소수점수(floating point number)
# - 불(boolean)
# - 리스트(list)
# - 튜플(tuple)
# - 딕셔너리(dictionary)

# %% [markdown]
# - type func.
#   - type(데이터)

# %%
print(type(2024))
print(type(3.14))
print(type('Python'))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ###정수형

# %%
a = 20
b = 0o34
c = 0xA1
d = 0b1110
print(a,b,c,d)
#print("",a,"\n",b,"\n",c,"\n",d)
# Out:
# 20 28 161 14

# %% [markdown]
# - 부동소수정수형
#   - 소수점 표현 방식
#   - 지수 표현 방식

# %% [markdown]
# - 불형
#   - True
#   - False

# %% [markdown]
# - 문자열형
#   - 문자열 연결 : 문자열1 + 문자열2

# %%
a = "Hi"
b = "Python"

print(a, "\t"+b)
print('Hi!'+'Python')

print('convergence' + 'programming')
print(23 - 25)
print(1.23 + 12.3e-1)
# Out:
# Hi 	Python
# Hi!Python
# convergenceprogramming
# -2
# 2.46

# %% [markdown]
# ##2.3 입력과 출력

# %% [markdown]
# ###입력

# %% [markdown]
# - input()

# %%
input()
# Out:
# 10
# '10'

# %%
name = input('이름: ')
age = input('나이: ')
print(name, '나이:', age)
# Out:
# 이름: 최하연
# 나이: 24
# 최하연 나이: 24

# %%
a = input('정수: ')
b = input('정수: ')
print(a-b)  #문자열을 뺄 수 없다
# Out:
# 정수: 5
# 정수: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1156abf25d4b> in <cell line: 0>()
#       1 a = input('정수: ')
#       2 b = input('정수: ')
# ----> 3 print(a-b)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
a = int(input('정수: '))
b = int(input('정수: '))
print(a - b)
# Out:
# 정수: 5
# 정수: 3
# 2

# %% [markdown]
# - 부동소수정수형의 문자열 입력 받기
#   - ***float(input())***

# %%
minute = float(input('분 단위 시간: '))
second = minute * 60
print(second, '초')
# Out:
# 분 단위 시간: 10
# 600.0 초

# %% [markdown]
# ###출력

# %%
print('반갑습니다')
score = 90
print('성적은', score, '입니다.')
# Out:
# 반갑습니다
# 성적은 90 입니다.

# %%
a = 25
b = 42
print(a, end = ' ')
print(b)
# Out:
# 25 42

# %%
print('안녕!')
print()
print('파이썬')
# Out:
# 안녕!
#
# 파이썬

# %%
name = '홍길동'
age = 20
print('이름은 ', name, '이고 나이는 ', age, '입니다.')
# Out:
# 이름은  홍길동 이고 나이는  20 입니다.

# %% [markdown]
# - f문자열
#   - print(f'....{변수}....)

# %%
name = '홍길동'
age = 20
print(f'이름은 {name}이고 나이는 {age}입니다.')
# Out:
# 이름은 홍길동이고 나이는 20입니다.

# %%
name = '홍길동'
age = 20
print(f'{name:2}:{age:3}')
# Out:
# 홍길동: 20

# %%
a = 25
b = 1234
c = 4
print(f'{a:5d}')
print(f'{b:5d}')
print(f'20{c:02d}')
# Out:
#    25
#  1234
# 2004

# %%
a = 3.14159265
print(f'{a}, {a:.3f}')
print(f'{a:7.3f}')
# Out:
# 3.14159265, 3.142
#   3.142

# %% [markdown]
# - 원의 넓이 구하기

# %%
pi = 3.14159265
radius = int(input('원의 반지름: '))
area = pi * radius * radius
print(f'원의 넓이: {area:.3f}')
# Out:
# 원의 반지름: 2
# 원의 넓이: 12.566

# %% [markdown]
# ##2.4 연산자

# %% [markdown]
# - 산술 연산자
# - 비교 연산자
# - 논리 연산자

# %% [markdown]
# ###산술 연산자

# %%
a = int(input('정수: '))
b = int(input('정수: '))
print(f'{a} + {b} = {a + b}')
print(f'{a} - {b} = {a - b}')
print(f'{a} * {b} = {a * b}')
print(f'{a} / {b} = {a / b}')
print(f'{a} // {b} = {a // b}')
print(f'{a} % {b} = {a % b}')
print(f'{a} ** {b} = {a ** b}')
# Out:
# 정수: 10
# 정수: 2
# 10 + 2 = 12
# 10 - 2 = 8
# 10 * 2 = 20
# 10 / 2 = 5.0
# 10 // 2 = 5
# 10 % 2 = 0
# 10 ** 2 = 100

# %% [markdown]
# - 정수 3개 평균 구하기

# %%
ave = 70 + 80 + 90 /3
print(ave)
# Out:
# 180.0

# %%
ave = (70 + 80 + 90) / 3
print(ave)
# Out:
# 80.0

# %%
a = 10
b = 20

print(a and b)
# Out:
# 20

# %% [markdown]
# ###연산자 우선순위

# %%
a = 2
b = 3
c = 4
a+b**c*a
# Out:
# 164

# %%
a-b+c
# Out:
# 8

# %% [markdown]
# - 괄호로 연산 순서 정하기
#   - ()사용 : 최우선 순위를 갖음

# %%
a - (b+c)
# Out:
# 0

# %% [markdown]
# - 남녀 비율 계산하기

# %%
male_num = int(input('남성 지원자 수: '))
female_num = int(input('여성 지원자 수: '))
total = male_num + female_num
print(f'남성 비율: {male_num/total:.2f} 여성 비율: {female_num/total:.2f}')
print(f'남성 비율: {(male_num/total)*100:.2f} 여성 비율: {(female_num/total)*100:.2f}')
# Out:
# 남성 지원자 수: 3
# 여성 지원자 수: 7
# 남성 비율: 0.30 여성 비율: 0.70
# 남성 비율: 30.00 여성 비율: 70.00

# %% [markdown]
# - 길이 단위 변환하기

# %%
cm = int(input('센티미터 단위 길이: '))
m = cm // 100
cm = cm % 100
print(f'{m}미터 {cm}센티미터')
# Out:
# 센티미터 단위 길이: 164
# 1미터 64센티미터

# %% [markdown]
# - 분 단위 시간을 시간과 분 단위로 변환하기

# %%
min = int(input('분 단위 시간: '))
hour = min // 60
min = min % 60
print(f'{hour}시간 {min}분')
# Out:
# 분 단위 시간: 123
# 2시간 3분

# %% [markdown]
# - 초 단위 시간을 시간,분,초 단위로 변환하기

# %%
second = int(input('초 단위 시간: '))
hour = second // (60*60)
second = second % (60*60)
min = second // 60
second = second % 60
print(f'{hour}시간 {min}분 {second}초')
# Out:
# 초 단위 시간: 12345
# 3시간 25분 45초

# %% [markdown]
# - 주문 금액 계산기 I

# %%
americano = int(input('아메리카노 주문 수: '))
latte = int(input('라떼 주문 수: '))
greentea = int(input('녹차 주문 수: '))
sum = americano*2000 + latte*3000 + greentea*2500
print('주문 금액:', sum)
# Out:
# 아메리카노 주문 수: 5
# 라떼 주문 수: 2
# 녹차 주문 수: 1
# 주문 금액: 18500

# %% [markdown]
# - 주문 금액 계산기 II

# %%
americano_price = 2000
latte_price = 3000
greentea_price = 2500

sum = 0

americano_num = int(input('아메리카노 주문 수: '))
sum += americano_num * americano_price

latte_num = int(input('라떼 주문 수: '))
sum += latte_num * latte_price

greentea_num = int(input('녹차 주문 수: '))
sum += greentea_num * greentea_price

print('주문 금액: ', sum)
# Out:
# 아메리카노 주문 수: 5
# 라떼 주문 수: 2
# 녹차 주문 수: 1
# 주문 금액:  18500

# %% [markdown]
# #예제

# %% [markdown]
# ##킬로미터를 마일로 변환

# %% [markdown]
# ## 섭씨를 화씨로 변환

# %% [markdown]
# ##평수를 제곱미터로 변환

# %% [markdown]
# ##킬로그램을 파운드로 변환
